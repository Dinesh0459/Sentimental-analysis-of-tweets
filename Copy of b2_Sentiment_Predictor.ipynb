# %% [markdown]
# ###Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###Importing dataset (from google drive)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###Data cleaning

# %%
import re
import nltk

nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

all_stopwords = stopwords.words('english')
all_stopwords.remove('not')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
string ="Food is good"
string = re.sub(r"[^a-zA-Z0-9]"," ",string)
string = string.lower()
string = string.split()
string = [ps.stem(word) for word in string if not word in set(all_stopwords)]

print(string)
# Out:
# ['food', 'good']

# %% [markdown]
# ###Data transformation

# %%
# Loading BoW dictionary
from sklearn.feature_extraction.text import CountVectorizer
import pickle
cvFile='/content/drive/MyDrive/DMA project/Project2_Sentiment_Analysis/c1_BoW_Sentiment_Model.pkl'
# cv = CountVectorizer(decode_error="replace", vocabulary=pickle.load(open('./drive/MyDrive/Colab Notebooks/2 Sentiment Analysis (Basic)/3.1 BoW_Sentiment Model.pkl', "rb")))
cv = pickle.load(open(cvFile, "rb"))

# %%
X_fresh = cv.transform(string).toarray()
X_fresh.shape
# Out:
# (2, 1420)

# %% [markdown]
# ###Predictions (via sentiment classifier)

# %%
import joblib
classifier = joblib.load('/content/drive/MyDrive/DMA project/Project2_Sentiment_Analysis/c2_Classifier_Sentiment_Model')

# %%
token = classifier.predict(X_fresh)
print(token)
# Out:
# [0 0]

# %%
positive_reviews = 0;
negative_reviews = 0;
for i in token:
  if i==1:
    positive_reviews=positive_reviews+1;
  else:
    negative_reviews=negative_reviews+1;

if positive_reviews>=negative_reviews:
  print("The Restaurant's got the Good FeedBack");
elif positive_reviews<negative_reviews:
  print("The Restaurant got the Negative FeedBack");
# Out:
# The Restaurant got the Negative FeedBack
